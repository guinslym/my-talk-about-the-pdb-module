# %% [markdown]
# ### Jupyter notebook

# %%
def divide(x):
    return x / 0

# %%
divide(5)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-c90a070d79a1> in <module>()
# ----> 1 divide(5)
#
# <ipython-input-1-111d3373c5f4> in divide(x)
#       1 def divide(x):
# ----> 2     return x / 0
#
# ZeroDivisionError: division by zero

# %%
debug
# Out:
# > <ipython-input-1-111d3373c5f4>(2)divide()
#       1 def divide(x):
# ----> 2     return x / 0
#
# ipdb> whos
# *** NameError: name 'whos' is not defined
# ipdb> help
#
# Documented commands (type help <topic>):
# ...
# EOF    c          d        h         next    pp       retval  u          whatis
# a      cl         debug    help      p       psource  run     unalias    where
# alias  clear      disable  ignore    pdef    q        rv      undisplay
# args   commands   display  interact  pdoc    quit     s       unt
# b      condition  down     j         pfile   r        source  until
# break  cont       enable   jump      pinfo   restart  step    up
# bt     continue   exit     n         pinfo2  return   tbreak  w
#
# Miscellaneous help topics:
# ...
# pdb  exec
#
# Undocumented commands:
# ...
# l  list  ll  longlist
